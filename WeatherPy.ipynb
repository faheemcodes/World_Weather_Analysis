# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
from config import weather_api_key
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# for coordinate in coordinates:
#     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 642

# %%
city_data = []

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b0bbbe03712d987841f7a0975381d3d'

# %%
city_url = url + "&q=" + cities[4].replace(" ","+")
city_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b0bbbe03712d987841f7a0975381d3d&q=tortoli'

# %%
city_data = []
set_count = 1
record_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

    # Indicate that Data Loading is complete.
    print("-----------------------------")
    print("Data Retrieval Complete      ")
    print("-----------------------------")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Processing Record 1 of Set 1 | ulladulla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 1 | tuktoyaktuk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 1 | kapaa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 1 | iqaluit
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 1 | tortoli
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 1 | honiara
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 1 | serafimovich
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 1 | yellowknife
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 1 | nikolskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 1 | rikitea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 1 | ushuaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 1 | taolanaro
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 1 | fairbanks
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 1 | puerto ayora
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 1 | carnarvon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 1 | mutsamudu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 1 | jamestown
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 1 | cherskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 1 | atuona
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 1 | tucurui
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 1 | san cristobal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 1 | kaitangata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 1 | vaini
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 1 | nanortalik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 1 | avarua
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 1 | ebano
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 1 | gannan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 1 | touros
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 1 | amderma
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 1 | kralendijk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 1 | constitucion
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 1 | kyshtovka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 1 | port alfred
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 1 | dwarka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 1 | tsiroanomandidy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 1 | garwa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 1 | saint george
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 1 | thompson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 1 | hilo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 1 | mataura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 1 | hobart
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 1 | cockburn harbour
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 1 | lebu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 1 | butaritari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 1 | ribeira grande
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 1 | ancud
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 1 | albany
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 1 | georgetown
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 1 | provideniya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 2 | bambous virieux
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 2 | klaksvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 2 | nouakchott
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 2 | lufilufi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 2 | cidreira
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 2 | ornskoldsvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 2 | fortuna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 2 | the pas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 2 | port blair
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 2 | gambela
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 2 | qaanaaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 2 | lata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 2 | isangel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 2 | busselton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 2 | bluff
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 2 | tura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 2 | port-gentil
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 2 | adrar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 2 | longyearbyen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 2 | muli
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 2 | lishui
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 2 | hunza
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 2 | riyadh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 2 | rungata
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 2 | obo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 2 | steinbach
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 2 | saint-philippe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 2 | berlevag
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 2 | bathsheba
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 2 | araouane
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 2 | san patricio
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 2 | vardo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 2 | cape town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 2 | dawson creek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 2 | hermanus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 2 | bonfim
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 2 | anloga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 2 | bethel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 2 | barrow
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 2 | chokurdakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 2 | kavieng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 2 | punta arenas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 2 | castro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 2 | makakilo city
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 2 | campbell river
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 2 | tiksi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 2 | amuntai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 3 | vostok
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 3 | laguna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 3 | narsaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 3 | palabuhanratu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 3 | krasnoselkup
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 3 | upata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 3 | neiafu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 3 | upernavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 3 | kemijarvi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 3 | chipinge
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 3 | pimentel
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 3 | kodiak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 3 | buala
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 3 | strezhevoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 3 | nizhneyansk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 3 | komsomolskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 3 | mitsamiouli
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 3 | maloshuyka
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 3 | moron
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 3 | torbay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 3 | kazalinsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 3 | sterling
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 3 | rawson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 3 | hithadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 3 | yangjiang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 3 | marsh harbour
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 3 | qinggang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 3 | kontagora
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 3 | vannes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 3 | ilulissat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 3 | new norfolk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 3 | harnosand
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 3 | mahebourg
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 3 | togitsu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 3 | yulara
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 3 | saint anthony
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 3 | bushehr
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 3 | bredasdorp
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 3 | arraial do cabo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 3 | port hardy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 3 | mys shmidta
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 3 | visnes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 3 | korla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 3 | solovetskiy
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 3 | bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 3 | wanning
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 3 | zhigansk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 3 | lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 4 | fort nelson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 4 | mehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 4 | ponta do sol
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 4 | saint-joseph
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 4 | guerrero negro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 4 | victoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 4 | dir
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 4 | esperance
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 4 | port elizabeth
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 4 | mackay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 4 | dikson
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 4 | mackenzie
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 4 | erenhot
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 4 | bodden town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 4 | margate
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 4 | manokwari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 4 | tasiilaq
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 4 | mogadishu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 4 | bengkulu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 4 | manaure
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 4 | faya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 4 | souillac
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 4 | saskylakh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 4 | chapais
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 4 | tahe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 4 | krasnomayskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 4 | port macquarie
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 4 | codrington
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 4 | dubovka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 4 | vila franca do campo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 4 | uyuni
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 4 | katsuura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 4 | kloulklubed
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 4 | coulihaut
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 4 | taburi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 4 | yanaul
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 4 | karpinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 4 | hovd
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 4 | sitka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 4 | tiznit
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 4 | asau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 4 | east london
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 4 | benghazi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 4 | naze
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 4 | sahrak
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 4 | grand gaube
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 4 | lompoc
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 4 | quatre cocos
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 4 | chifeng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 4 | bonavista
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 5 | ucluelet
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 5 | nauen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 5 | ixtapa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 5 | cefalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 5 | airai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 5 | bajil
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 5 | barentsburg
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 5 | qingdao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 5 | sao filipe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 5 | vanimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 5 | grafton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 5 | yazoo city
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 5 | kuytun
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 5 | merauke
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 5 | homer
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 5 | mar del plata
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 5 | nome
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 5 | moree
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 5 | pevek
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 5 | kochi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 5 | hami
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 5 | ruteng
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 5 | lavrentiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 5 | chuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 5 | san andres
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 5 | saint-pierre
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 5 | luderitz
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 5 | sucre
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 5 | washougal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 5 | north myrtle beach
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 5 | ordu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 5 | lensk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 5 | azle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 5 | mount gambier
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 5 | meadow lake
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 5 | amparafaravola
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 5 | nanakuli
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 5 | cabo san lucas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 5 | labuhan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 5 | zhengjiatun
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 5 | sembakung
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 5 | kirundo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 5 | paamiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 5 | windsor locks
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 5 | la tijera
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 5 | dolbeau
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 5 | capitao poco
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 5 | sozimskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 5 | yomitan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 5 | wahran
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 6 | makarov
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 6 | urumqi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 6 | thinadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 6 | nemuro
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 6 | bonthe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 6 | dingle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 6 | salina cruz
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 6 | noumea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 6 | santa lucia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 6 | richards bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 6 | khuldabad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 6 | saku
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 6 | inderka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 6 | ewa beach
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 6 | palmer
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 6 | waingapu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 6 | blytheville
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 6 | college
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 6 | clyde river
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 6 | duz
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 6 | half moon bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 6 | bolungarvik
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 6 | meulaboh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 6 | kudahuvadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 6 | imamoglu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 6 | kruisfontein
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 6 | kiri buru
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 6 | khatanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 6 | vao
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 6 | qasigiannguit
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 6 | katsiveli
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 6 | aklavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 6 | kastamonu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 6 | dunedin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 6 | nancha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 6 | diffa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 6 | fukue
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 6 | kokkola
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 6 | auki
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 6 | tzermiadon
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 6 | boyolangu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 6 | port keats
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 6 | lima
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 6 | sumbawa
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 6 | karaul
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 6 | sisimiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 6 | tuatapere
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 6 | yumen
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 6 | cayenne
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 7 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 7 | nuevo imperial
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 7 | chumikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 7 | bucerias
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 7 | severo-kurilsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 7 | mount isa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 7 | klyuchevskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 7 | saint-denis
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 7 | yei
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 7 | eravur
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 7 | samarai
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 7 | sorland
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 7 | puerto leguizamo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 7 | steamboat springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 7 | bereda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 7 | namibe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 7 | faanui
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 7 | manaus
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 7 | aksu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 7 | poronaysk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 7 | smithers
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 7 | price
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 7 | ketchikan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 7 | edd
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 7 | flin flon
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 7 | sumbe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 7 | voznesenye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 7 | saldanha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 7 | haines junction
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 7 | awbari
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 7 | weligama
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 7 | coquimbo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 7 | ponta delgada
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 7 | ginda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 7 | necochea
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 7 | gwadar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 7 | axim
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 7 | los llanos de aridane
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 7 | bitam
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 7 | turan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 7 | tarauaca
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 7 | road town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 7 | buraydah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 7 | stokmarknes
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 7 | kidal
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 7 | lorengau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 7 | datia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 7 | kathmandu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 7 | lerwick
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 7 | harper
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 8 | gillette
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 8 | panshi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 8 | port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 8 | ipojuca
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 8 | torquay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 8 | sinnamary
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 8 | attawapiskat
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 8 | riviere-au-renard
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 8 | datong
# -----------------------------
# Data Retrieval Complete
# ...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 11 | cockburn town
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 11 | miandrivazo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 11 | atasu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 11 | gevgelija
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 11 | te anau
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 11 | celendin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 11 | palaia fokaia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 11 | krasnovishersk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 11 | srednekolymsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 11 | piskavica
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 11 | nago
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 11 | otradnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 11 | saint-augustin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 11 | angoche
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 11 | geraldton
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 11 | genthin
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 11 | rafaela
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 11 | maputo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 11 | diphu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 11 | artyk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 11 | barabinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 11 | jomalig
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 11 | lithia springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 11 | fevralsk
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 11 | manta
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 11 | saquena
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 11 | pacific grove
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 12 | miranda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 12 | hualmay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 12 | scarborough
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 12 | gisborne
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 12 | banda aceh
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 12 | ratholo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 12 | kitgum
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 12 | rawannawi
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 12 | victor harbor
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 12 | bardiyah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 12 | safford
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 12 | dong hoi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 12 | taksimo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 12 | kutum
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 12 | kampong thum
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 12 | romanovka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 12 | chandla
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 12 | juegang
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 12 | karratha
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 12 | altay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 12 | chauk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 12 | north bend
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 12 | bilibino
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 12 | jalu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 12 | chinsali
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 12 | grindavik
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 12 | matay
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 12 | santo antonio do ica
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 12 | san juan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 12 | vaitupu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 12 | sorong
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 12 | perth
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 12 | trinidad
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 12 | nibbar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 12 | zheleznodorozhnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 12 | gberia fotombu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 12 | lamu
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 12 | opuwo
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 12 | cherusti
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 12 | kandrian
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 12 | ostrovnoy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 12 | morondava
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 43 of Set 12 | guaruja
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 44 of Set 12 | gat
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 45 of Set 12 | comodoro rivadavia
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 46 of Set 12 | kristinehamn
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 47 of Set 12 | moranbah
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 48 of Set 12 | novoselitskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 49 of Set 12 | uray
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 50 of Set 12 | genhe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 1 of Set 13 | bloomfield
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 2 of Set 13 | bourail
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 3 of Set 13 | kysyl-syr
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 4 of Set 13 | maxixe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 5 of Set 13 | itoman
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 6 of Set 13 | dzhusaly
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 7 of Set 13 | ust-uda
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 8 of Set 13 | bam
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 9 of Set 13 | salinas
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 10 of Set 13 | biak
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 11 of Set 13 | dauriya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 12 of Set 13 | zarate
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 13 of Set 13 | songjianghe
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 14 of Set 13 | seabra
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 15 of Set 13 | port lincoln
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 16 of Set 13 | praya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 17 of Set 13 | nicoya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 18 of Set 13 | wuzhou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 19 of Set 13 | riberalta
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 20 of Set 13 | nhulunbuy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 21 of Set 13 | port-de-bouc
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 22 of Set 13 | mabaruma
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 23 of Set 13 | arman
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 24 of Set 13 | kolosovka
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 25 of Set 13 | gushikawa
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 26 of Set 13 | high level
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 27 of Set 13 | omegna
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 28 of Set 13 | ajdabiya
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 29 of Set 13 | shiyan
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 30 of Set 13 | champerico
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 31 of Set 13 | yugorsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 32 of Set 13 | capaci
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 33 of Set 13 | pilar
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 34 of Set 13 | sechura
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 35 of Set 13 | chiredzi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 36 of Set 13 | galle
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 37 of Set 13 | polunochnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 38 of Set 13 | gaomi
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 39 of Set 13 | sorvag
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 40 of Set 13 | bangassou
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 41 of Set 13 | ferrol
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# Processing Record 42 of Set 13 | limbe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.47,
#   'Max Temp': 46.99,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:11'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 42.8,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:11'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 82.99,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:11'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 59,
#   'Humidity': 41,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:51:51'},
#  {'City': 'Tortoli',
#   'Lat': 39.93,
#   'Lng': 9.66,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'IT',
#   'Date': '2020-08-27 19:53:12'},
#  {'City': 'Honiara',
#   'Lat': -9.43,
#   'Lng': 159.95,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'SB',
#   'Date': '2020-08-27 19:52:53'},
#  {'City': 'Serafimovich',
#   'Lat': 49.58,
#   'Lng': 42.74,
#   'Max Temp': 64,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:12'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 60.8,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:50:51'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:12'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 67.93,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 1.39,
#   'Country': 'PF',
#   'Date': '2020-08-27 19:53:12'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 37.4,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:50:19'},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 3.78,
#   'Country': 'US',
#   'Date': '2020-08-27 19:52:06'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 87,
#   'Wind Speed': 20.8,
#   'Country': 'EC',
#   'Date': '2020-08-27 19:53:13'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Max Temp': 66.2,
#   'Humidity': 100,
#   'Cloudiness': 89,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:13'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 20.8,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:13'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 40.66,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:13'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 78.71,
#   'Humidity': 75,
#   'Cloudiness': 33,
#   'Wind Speed': 21.41,
#   'Country': 'PF',
#   'Date': '2020-08-27 19:53:13'},
#  {'City': 'Tucurui',
#   'Lat': -3.77,
#   'Lng': -49.67,
#   'Max Temp': 93.52,
#   'Humidity': 40,
#   'Cloudiness': 58,
#   'Wind Speed': 2.51,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:53:13'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Max Temp': 91.4,
#   'Humidity': 49,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'VE',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Max Temp': 37.99,
#   'Humidity': 89,
#   'Cloudiness': 68,
#   'Wind Speed': 5.26,
#   'Country': 'NZ',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'TO',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Nanortalik',
#   'Lat': 60.14,
#   'Lng': -45.24,
#   'Max Temp': 48.49,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 13.82,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 53,
#   'Wind Speed': 3.36,
#   'Country': 'CK',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Gannan',
#   'Lat': 47.91,
#   'Lng': 123.5,
#   'Max Temp': 60.82,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 16.22,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Max Temp': 80.6,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:53:14'},
#  {'City': 'Kralendijk',
#   'Lat': 12.15,
#   'Lng': -68.27,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'BQ',
#   'Date': '2020-08-27 19:53:16'},
#  {'City': 'Constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 53.26,
#   'Humidity': 64,
#   'Cloudiness': 17,
#   'Wind Speed': 8.16,
#   'Country': 'CL',
#   'Date': '2020-08-27 19:50:03'},
#  {'City': 'Kyshtovka',
#   'Lat': 56.55,
#   'Lng': 76.63,
#   'Max Temp': 52.16,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:16'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 61.25,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 18.81,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:16'},
#  {'City': 'Dwarka',
#   'Lat': 22.24,
#   'Lng': 68.97,
#   'Max Temp': 81.93,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 13.44,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:16'},
#  {'City': 'Tsiroanomandidy',
#   'Lat': -18.77,
#   'Lng': 46.03,
#   'Max Temp': 74.28,
#   'Humidity': 45,
#   'Cloudiness': 98,
#   'Wind Speed': 0.2,
#   'Country': 'MG',
#   'Date': '2020-08-27 19:53:16'},
#  {'City': 'Garwa',
#   'Lat': 24.18,
#   'Lng': 83.82,
#   'Max Temp': 75.49,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 10.56,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:16'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 102,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-08-27 19:51:28'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 69.8,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:17'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:17'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 45,
#   'Humidity': 72,
#   'Cloudiness': 59,
#   'Wind Speed': 11.01,
#   'Country': 'NZ',
#   'Date': '2020-08-27 19:53:17'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 48,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:48:34'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 51.69,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 10.4,
#   'Country': 'CL',
#   'Date': '2020-08-27 19:53:17'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 82.36,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Country': 'KI',
#   'Date': '2020-08-27 19:53:17'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'PT',
#   'Date': '2020-08-27 19:53:17'},
#  {'City': 'Ancud',
#   'Lat': -41.87,
#   'Lng': -73.82,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'CL',
#   'Date': '2020-08-27 19:53:18'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 64,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.79,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:18'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 1.5,
#   'Country': 'MY',
#   'Date': '2020-08-27 19:50:01'},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 49.19,
#   'Humidity': 80,
#   'Cloudiness': 25,
#   'Wind Speed': 2.64,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:18'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'MU',
#   'Date': '2020-08-27 19:53:18'},
#  {'City': 'Klaksvik',
#   'Lat': 62.23,
#   'Lng': -6.59,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'FO',
#   'Date': '2020-08-27 19:53:18'},
#  {'City': 'Nouakchott',
#   'Lat': 18.09,
#   'Lng': -15.98,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 17.22,
#   'Country': 'MR',
#   'Date': '2020-08-27 19:53:18'},
#  {'City': 'Lufilufi',
#   'Lat': -13.87,
#   'Lng': -171.6,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 26.02,
#   'Country': 'WS',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 66.83,
#   'Humidity': 68,
#   'Cloudiness': 21,
#   'Wind Speed': 6.69,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:52:11'},
#  {'City': 'Ornskoldsvik',
#   'Lat': 63.29,
#   'Lng': 18.72,
#   'Max Temp': 46.4,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'SE',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Max Temp': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'The Pas',
#   'Lat': 53.83,
#   'Lng': -101.25,
#   'Max Temp': 73.4,
#   'Humidity': 43,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:51:17'},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 81.54,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 7.4,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'Gambela',
#   'Lat': 8.25,
#   'Lng': 34.58,
#   'Max Temp': 70.83,
#   'Humidity': 85,
#   'Cloudiness': 79,
#   'Wind Speed': 3.89,
#   'Country': 'ET',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 39.43,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 9.82,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'Lata',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 72,
#   'Humidity': 83,
#   'Cloudiness': 10,
#   'Wind Speed': 4,
#   'Country': 'PT',
#   'Date': '2020-08-27 19:53:19'},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 72.61,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 18.99,
#   'Country': 'VU',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 46.99,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 4.88,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 45,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 11.01,
#   'Country': 'NZ',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Max Temp': 74.43,
#   'Humidity': 89,
#   'Cloudiness': 18,
#   'Wind Speed': 5.75,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.72,
#   'Lng': 8.78,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 15.75,
#   'Country': 'GA',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Adrar',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Max Temp': 97.88,
#   'Humidity': 26,
#   'Cloudiness': 39,
#   'Wind Speed': 8.23,
#   'Country': 'MR',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 39.2,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Country': 'SJ',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Muli',
#   'Lat': 2.92,
#   'Lng': 73.57,
#   'Max Temp': 83.66,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 11.36,
#   'Country': 'MV',
#   'Date': '2020-08-27 19:53:20'},
#  {'City': 'Lishui',
#   'Lat': 28.46,
#   'Lng': 119.91,
#   'Max Temp': 76.39,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 2.82,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:21'},
#  {'City': 'Riyadh',
#   'Lat': 24.69,
#   'Lng': 46.72,
#   'Max Temp': 95,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'SA',
#   'Date': '2020-08-27 19:52:32'},
#  {'City': 'Obo',
#   'Lat': 5.4,
#   'Lng': 26.49,
#   'Max Temp': 69.71,
#   'Humidity': 94,
#   'Cloudiness': 38,
#   'Wind Speed': 1.19,
#   'Country': 'CF',
#   'Date': '2020-08-27 19:53:21'},
#  {'City': 'Steinbach',
#   'Lat': 50.17,
#   'Lng': 8.57,
#   'Max Temp': 72,
#   'Humidity': 63,
#   'Cloudiness': 55,
#   'Wind Speed': 5.82,
#   'Country': 'DE',
#   'Date': '2020-08-27 19:53:21'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 35,
#   'Wind Speed': 6.93,
#   'Country': 'RE',
#   'Date': '2020-08-27 19:53:21'},
#  {'City': 'Berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 46.4,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 20.8,
#   'Country': 'NO',
#   'Date': '2020-08-27 19:53:21'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Max Temp': 84,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 16.42,
#   'Country': 'BB',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'Araouane',
#   'Lat': 18.9,
#   'Lng': -3.53,
#   'Max Temp': 101.25,
#   'Humidity': 19,
#   'Cloudiness': 3,
#   'Wind Speed': 7.81,
#   'Country': 'ML',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'San Patricio',
#   'Lat': 19.22,
#   'Lng': -104.7,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'MX',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Country': 'NO',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 57,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:51:16'},
#  {'City': 'Dawson Creek',
#   'Lat': 55.77,
#   'Lng': -120.24,
#   'Max Temp': 64.4,
#   'Humidity': 45,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 55,
#   'Humidity': 92,
#   'Cloudiness': 59,
#   'Wind Speed': 4,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'Bonfim',
#   'Lat': 3.08,
#   'Lng': -59.95,
#   'Max Temp': 90.09,
#   'Humidity': 53,
#   'Cloudiness': 39,
#   'Wind Speed': 2.68,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:53:22'},
#  {'City': 'Anloga',
#   'Lat': 5.79,
#   'Lng': 0.9,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'GH',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Max Temp': 87.01,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 18.34,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 35.33,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.96,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Max Temp': 81.36,
#   'Humidity': 75,
#   'Cloudiness': 77,
#   'Wind Speed': 5.37,
#   'Country': 'PG',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 39,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 28.86,
#   'Country': 'CL',
#   'Date': '2020-08-27 19:52:11'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 69.31,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Makakilo City',
#   'Lat': 21.35,
#   'Lng': -158.09,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:23'},
#  {'City': 'Campbell River',
#   'Lat': 50.02,
#   'Lng': -125.24,
#   'Max Temp': 68,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:52:10'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 39.04,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 3.27,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Amuntai',
#   'Lat': -2.42,
#   'Lng': 115.25,
#   'Max Temp': 73.06,
#   'Humidity': 90,
#   'Cloudiness': 62,
#   'Wind Speed': 1.34,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Vostok',
#   'Lat': 46.49,
#   'Lng': 135.88,
#   'Max Temp': 61.54,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 6.33,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Laguna',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 84,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Narsaq',
#   'Lat': 60.92,
#   'Lng': -46.05,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.47,
#   'Max Temp': 52.88,
#   'Humidity': 90,
#   'Cloudiness': 3,
#   'Wind Speed': 4.68,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Upata',
#   'Lat': 8.01,
#   'Lng': -62.4,
#   'Max Temp': 93,
#   'Humidity': 53,
#   'Cloudiness': 93,
#   'Wind Speed': 3,
#   'Country': 'VE',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Neiafu',
#   'Lat': -18.65,
#   'Lng': -173.98,
#   'Max Temp': 75.2,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 15.82,
#   'Country': 'TO',
#   'Date': '2020-08-27 19:53:24'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 43.79,
#   'Humidity': 70,
#   'Cloudiness': 95,
#   'Wind Speed': 8.05,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Kemijarvi',
#   'Lat': 66.71,
#   'Lng': 27.43,
#   'Max Temp': 41.04,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 2.39,
#   'Country': 'FI',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Chipinge',
#   'Lat': -20.19,
#   'Lng': 32.62,
#   'Max Temp': 59.5,
#   'Humidity': 86,
#   'Cloudiness': 11,
#   'Wind Speed': 7.14,
#   'Country': 'ZW',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Pimentel',
#   'Lat': -6.84,
#   'Lng': -79.93,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 19,
#   'Wind Speed': 17.22,
#   'Country': 'PE',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-08-27 19:50:29'},
#  {'City': 'Buala',
#   'Lat': -8.14,
#   'Lng': 159.59,
#   'Max Temp': 80.11,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.83,
#   'Country': 'SB',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Strezhevoy',
#   'Lat': 60.73,
#   'Lng': 77.59,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'UZ',
#   'Date': '2020-08-27 19:53:25'},
#  {'City': 'Mitsamiouli',
#   'Lat': -11.38,
#   'Lng': 43.28,
#   'Max Temp': 76.35,
#   'Humidity': 77,
#   'Cloudiness': 35,
#   'Wind Speed': 4.12,
#   'Country': 'KM',
#   'Date': '2020-08-27 19:53:26'},
#  {'City': 'Moron',
#   'Lat': -34.65,
#   'Lng': -58.62,
#   'Max Temp': 66.99,
#   'Humidity': 52,
#   'Cloudiness': 2,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:48:35'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 64.99,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:26'},
#  {'City': 'Sterling',
#   'Lat': 39.01,
#   'Lng': -77.43,
#   'Max Temp': 91.99,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:26'},
#  {'City': 'Rawson',
#   'Lat': -43.3,
#   'Lng': -65.1,
#   'Max Temp': 61.95,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 15.14,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:53:26'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 80.47,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 10.07,
#   'Country': 'MV',
#   'Date': '2020-08-27 19:53:26'},
#  {'City': 'Yangjiang',
#   'Lat': 21.85,
#   'Lng': 111.97,
#   'Max Temp': 77.77,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 3.38,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.54,
#   'Lng': -77.06,
#   'Max Temp': 85.05,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 11.1,
#   'Country': 'BS',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Qinggang',
#   'Lat': 46.68,
#   'Lng': 126.08,
#   'Max Temp': 63.9,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 19.22,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Kontagora',
#   'Lat': 10.4,
#   'Lng': 5.47,
#   'Max Temp': 73.96,
#   'Humidity': 94,
#   'Cloudiness': 85,
#   'Wind Speed': 4.36,
#   'Country': 'NG',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Vannes',
#   'Lat': 47.83,
#   'Lng': -2.5,
#   'Max Temp': 63,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'FR',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Ilulissat',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Max Temp': 44.6,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 48,
#   'Humidity': 77,
#   'Cloudiness': 23,
#   'Wind Speed': 5.99,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Harnosand',
#   'Lat': 62.63,
#   'Lng': 17.94,
#   'Max Temp': 54,
#   'Humidity': 76,
#   'Cloudiness': 76,
#   'Wind Speed': 5.82,
#   'Country': 'SE',
#   'Date': '2020-08-27 19:53:27'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'MU',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Togitsu',
#   'Lat': 32.83,
#   'Lng': 129.85,
#   'Max Temp': 78.01,
#   'Humidity': 88,
#   'Cloudiness': 68,
#   'Wind Speed': 5.99,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Yulara',
#   'Lat': -25.24,
#   'Lng': 130.99,
#   'Max Temp': 60.8,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Saint Anthony',
#   'Lat': 45.02,
#   'Lng': -93.22,
#   'Max Temp': 87.01,
#   'Humidity': 45,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Bushehr',
#   'Lat': 28.97,
#   'Lng': 50.84,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 21,
#   'Wind Speed': 4.7,
#   'Country': 'IR',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 55.4,
#   'Humidity': 87,
#   'Cloudiness': 61,
#   'Wind Speed': 6.93,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.87,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Port Hardy',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 55.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:28'},
#  {'City': 'Visnes',
#   'Lat': 59.36,
#   'Lng': 5.22,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 19.46,
#   'Country': 'NO',
#   'Date': '2020-08-27 19:53:29'},
#  {'City': 'Korla',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Max Temp': 75,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 8.01,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:29'},
#  {'City': 'Bend',
#   'Lat': 44.06,
#   'Lng': -121.32,
#   'Max Temp': 80.01,
#   'Humidity': 7,
#   'Cloudiness': 1,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-08-27 19:52:33'},
#  {'City': 'Wanning',
#   'Lat': 18.8,
#   'Lng': 110.4,
#   'Max Temp': 78.82,
#   'Humidity': 84,
#   'Cloudiness': 65,
#   'Wind Speed': 2.77,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:29'},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 44.4,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 5.12,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:29'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 74.68,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.84,
#   'Country': 'PT',
#   'Date': '2020-08-27 19:53:29'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Max Temp': 64.4,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:29'},
#  {'City': 'Mehamn',
#   'Lat': 71.04,
#   'Lng': 27.85,
#   'Max Temp': 46.4,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'NO',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Max Temp': 81,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 28.86,
#   'Country': 'PT',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.37,
#   'Lng': 55.62,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 17,
#   'Wind Speed': 6.93,
#   'Country': 'RE',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Max Temp': 91.17,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 10,
#   'Country': 'MX',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Victoria',
#   'Lat': 22.29,
#   'Lng': 114.16,
#   'Max Temp': 82.99,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'HK',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Dir',
#   'Lat': 35.21,
#   'Lng': 71.88,
#   'Max Temp': 67.91,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'PK',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Esperance',
#   'Lat': -33.87,
#   'Lng': 121.9,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 17.22,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:30'},
#  {'City': 'Mackay',
#   'Lat': -21.15,
#   'Lng': 149.2,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 5,
#   'Wind Speed': 11.41,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:51:56'},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 47.17,
#   'Humidity': 86,
#   'Cloudiness': 3,
#   'Wind Speed': 12.12,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Mackenzie',
#   'Lat': 55.3,
#   'Lng': -123.17,
#   'Max Temp': 51.8,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 3.53,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 69.57,
#   'Humidity': 55,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Bodden Town',
#   'Lat': 19.28,
#   'Lng': -81.25,
#   'Max Temp': 89.01,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 27.51,
#   'Country': 'KY',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 63,
#   'Humidity': 92,
#   'Cloudiness': 89,
#   'Wind Speed': 5.99,
#   'Country': 'GB',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Manokwari',
#   'Lat': -0.87,
#   'Lng': 134.08,
#   'Max Temp': 78.31,
#   'Humidity': 74,
#   'Cloudiness': 12,
#   'Wind Speed': 4.5,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:31'},
#  {'City': 'Mogadishu',
#   'Lat': 2.04,
#   'Lng': 45.34,
#   'Max Temp': 76.66,
#   'Humidity': 84,
#   'Cloudiness': 2,
#   'Wind Speed': 13.49,
#   'Country': 'SO',
#   'Date': '2020-08-27 19:52:57'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 75.22,
#   'Humidity': 83,
#   'Cloudiness': 17,
#   'Wind Speed': 5.26,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:51:29'},
#  {'City': 'Manaure',
#   'Lat': 11.78,
#   'Lng': -72.44,
#   'Max Temp': 91.42,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 17.05,
#   'Country': 'CO',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Faya',
#   'Lat': 18.39,
#   'Lng': 42.45,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 74,
#   'Wind Speed': 6.67,
#   'Country': 'SA',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'MU',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 50.31,
#   'Humidity': 73,
#   'Cloudiness': 24,
#   'Wind Speed': 3.22,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Chapais',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 55.4,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Tahe',
#   'Lat': 52.33,
#   'Lng': 124.73,
#   'Max Temp': 43.52,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Krasnomayskiy',
#   'Lat': 57.62,
#   'Lng': 34.41,
#   'Max Temp': 55.22,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.93,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:32'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.43,
#   'Lng': 152.92,
#   'Max Temp': 39.2,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 43.5,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 7.61,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Dubovka',
#   'Lat': 49.06,
#   'Lng': 44.83,
#   'Max Temp': 69.8,
#   'Humidity': 32,
#   'Cloudiness': 68,
#   'Wind Speed': 6.71,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.72,
#   'Lng': -25.43,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'PT',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Uyuni',
#   'Lat': -20.46,
#   'Lng': -66.83,
#   'Max Temp': 59.29,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 16.28,
#   'Country': 'BO',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 82.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'PW',
#   'Date': '2020-08-27 19:53:33'},
#  {'City': 'Yanaul',
#   'Lat': 56.27,
#   'Lng': 54.93,
#   'Max Temp': 61.23,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 3.51,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Karpinsk',
#   'Lat': 59.77,
#   'Lng': 60.01,
#   'Max Temp': 55.24,
#   'Humidity': 95,
#   'Cloudiness': 20,
#   'Wind Speed': 4.99,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Hovd',
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 56.32,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'MN',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Max Temp': 59,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Tiznit',
#   'Lat': 29.58,
#   'Lng': -9.5,
#   'Max Temp': 94.62,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 6.33,
#   'Country': 'MA',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Asau',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Max Temp': 71.6,
#   'Humidity': 49,
#   'Cloudiness': 76,
#   'Wind Speed': 2.24,
#   'Country': 'RO',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 63.32,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 5.84,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Benghazi',
#   'Lat': 32.12,
#   'Lng': 20.07,
#   'Max Temp': 79.74,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 13.49,
#   'Country': 'LY',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Naze',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 80.6,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:53:34'},
#  {'City': 'Grand Gaube',
#   'Lat': -20.01,
#   'Lng': 57.66,
#   'Max Temp': 70,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 5.01,
#   'Country': 'MU',
#   'Date': '2020-08-27 19:53:35'},
#  {'City': 'Lompoc',
#   'Lat': 34.64,
#   'Lng': -120.46,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:35'},
#  {'City': 'Quatre Cocos',
#   'Lat': -20.21,
#   'Lng': 57.76,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'MU',
#   'Date': '2020-08-27 19:53:35'},
#  {'City': 'Chifeng',
#   'Lat': 42.27,
#   'Lng': 118.96,
#   'Max Temp': 64.11,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:35'},
#  {'City': 'Bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Max Temp': 64.99,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 13,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:35'},
#  {'City': 'Ucluelet',
#   'Lat': 48.93,
#   'Lng': -125.55,
#   'Max Temp': 57.2,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:52:47'},
#  {'City': 'Nauen',
#   'Lat': 52.61,
#   'Lng': 12.87,
#   'Max Temp': 60.01,
#   'Humidity': 10,
#   'Cloudiness': 99,
#   'Wind Speed': 3.74,
#   'Country': 'DE',
#   'Date': '2020-08-27 19:53:35'},
#  {'City': 'Ixtapa',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'MX',
#   'Date': '2020-08-27 19:49:40'},
#  {'City': 'Cefalu',
#   'Lat': 38.04,
#   'Lng': 14.02,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 2.73,
#   'Country': 'IT',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Max Temp': 58.59,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 4.09,
#   'Country': 'TL',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Bajil',
#   'Lat': 15.06,
#   'Lng': 43.29,
#   'Max Temp': 91.26,
#   'Humidity': 51,
#   'Cloudiness': 89,
#   'Wind Speed': 1.57,
#   'Country': 'YE',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Qingdao',
#   'Lat': 36.1,
#   'Lng': 120.37,
#   'Max Temp': 73,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Max Temp': 78.64,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.15,
#   'Country': 'CV',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Max Temp': 78.15,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 4.47,
#   'Country': 'PG',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Grafton',
#   'Lat': 42.21,
#   'Lng': -71.69,
#   'Max Temp': 63,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.41,
#   'Country': 'US',
#   'Date': '2020-08-27 19:48:51'},
#  {'City': 'Yazoo City',
#   'Lat': 32.86,
#   'Lng': -90.41,
#   'Max Temp': 84,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:36'},
#  {'City': 'Kuytun',
#   'Lat': 54.34,
#   'Lng': 101.5,
#   'Max Temp': 51.1,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Merauke',
#   'Lat': -8.47,
#   'Lng': 140.33,
#   'Max Temp': 76.41,
#   'Humidity': 83,
#   'Cloudiness': 6,
#   'Wind Speed': 15.57,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Homer',
#   'Lat': 59.64,
#   'Lng': -151.55,
#   'Max Temp': 55,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Max Temp': 66.2,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:49:38'},
#  {'City': 'Nome',
#   'Lat': 64.5,
#   'Lng': -165.41,
#   'Max Temp': 59,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Moree',
#   'Lat': -29.47,
#   'Lng': 149.85,
#   'Max Temp': 37.4,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Max Temp': 37.69,
#   'Humidity': 91,
#   'Cloudiness': 13,
#   'Wind Speed': 3.49,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Kochi',
#   'Lat': 9.94,
#   'Lng': 76.26,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 73.2,
#   'Humidity': 20,
#   'Cloudiness': 50,
#   'Wind Speed': 14.14,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:37'},
#  {'City': 'Ruteng',
#   'Lat': -8.61,
#   'Lng': 120.47,
#   'Max Temp': 59.63,
#   'Humidity': 91,
#   'Cloudiness': 3,
#   'Wind Speed': 1.57,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 48.45,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 2.51,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 55.89,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Country': 'UY',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'San Andres',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'CO',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'Saint-Pierre',
#   'Lat': -21.34,
#   'Lng': 55.48,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'RE',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'Luderitz',
#   'Lat': -26.65,
#   'Lng': 15.16,
#   'Max Temp': 55.87,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 19.13,
#   'Country': 'NA',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'Sucre',
#   'Lat': -19.03,
#   'Lng': -65.26,
#   'Max Temp': 70.03,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 13.29,
#   'Country': 'BO',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'Washougal',
#   'Lat': 45.58,
#   'Lng': -122.35,
#   'Max Temp': 75,
#   'Humidity': 49,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:38'},
#  {'City': 'North Myrtle Beach',
#   'Lat': 33.82,
#   'Lng': -78.68,
#   'Max Temp': 91.99,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 13.87,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:05'},
#  {'City': 'Ordu',
#   'Lat': 40.91,
#   'Lng': 37.68,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'TR',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Lensk',
#   'Lat': 60.73,
#   'Lng': 114.93,
#   'Max Temp': 45.68,
#   'Humidity': 62,
#   'Cloudiness': 33,
#   'Wind Speed': 7.4,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Azle',
#   'Lat': 32.9,
#   'Lng': -97.55,
#   'Max Temp': 93.99,
#   'Humidity': 41,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Max Temp': 37.4,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Meadow Lake',
#   'Lat': 34.8,
#   'Lng': -106.54,
#   'Max Temp': 89.6,
#   'Humidity': 19,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Amparafaravola',
#   'Lat': -17.58,
#   'Lng': 48.22,
#   'Max Temp': 57.85,
#   'Humidity': 94,
#   'Cloudiness': 53,
#   'Wind Speed': 1.7,
#   'Country': 'MG',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Nanakuli',
#   'Lat': 21.39,
#   'Lng': -158.15,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:39'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Max Temp': 93.2,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'MX',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Max Temp': 76.24,
#   'Humidity': 79,
#   'Cloudiness': 57,
#   'Wind Speed': 8.14,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Zhengjiatun',
#   'Lat': 43.51,
#   'Lng': 123.51,
#   'Max Temp': 67.41,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Sembakung',
#   'Lat': 3.82,
#   'Lng': 117.25,
#   'Max Temp': 73.26,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 1.86,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Kirundo',
#   'Lat': -2.58,
#   'Lng': 30.17,
#   'Max Temp': 68,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'BI',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Paamiut',
#   'Lat': 61.99,
#   'Lng': -49.67,
#   'Max Temp': 43.81,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Windsor Locks',
#   'Lat': 41.93,
#   'Lng': -72.63,
#   'Max Temp': 72,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'La Tijera',
#   'Lat': 19.9,
#   'Lng': -104.4,
#   'Max Temp': 61.11,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'MX',
#   'Date': '2020-08-27 19:53:40'},
#  {'City': 'Capitao Poco',
#   'Lat': -1.75,
#   'Lng': -47.06,
#   'Max Temp': 83.28,
#   'Humidity': 78,
#   'Cloudiness': 4,
#   'Wind Speed': 5.77,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Sozimskiy',
#   'Lat': 59.74,
#   'Lng': 52.25,
#   'Max Temp': 52.52,
#   'Humidity': 95,
#   'Cloudiness': 30,
#   'Wind Speed': 3.31,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Makarov',
#   'Lat': 48.63,
#   'Lng': 142.8,
#   'Max Temp': 59.7,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 4.61,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Urumqi',
#   'Lat': 43.8,
#   'Lng': 87.6,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.53,
#   'Lng': 72.93,
#   'Max Temp': 82.35,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'MV',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 66.36,
#   'Humidity': 99,
#   'Cloudiness': 94,
#   'Wind Speed': 7.74,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Bonthe',
#   'Lat': 7.53,
#   'Lng': -12.51,
#   'Max Temp': 77.32,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 10.09,
#   'Country': 'SL',
#   'Date': '2020-08-27 19:53:41'},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 75.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.53,
#   'Country': 'PH',
#   'Date': '2020-08-27 19:53:42'},
#  {'City': 'Salina Cruz',
#   'Lat': 16.17,
#   'Lng': -95.2,
#   'Max Temp': 85.03,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'MX',
#   'Date': '2020-08-27 19:53:42'},
#  {'City': 'Noumea',
#   'Lat': -22.28,
#   'Lng': 166.46,
#   'Max Temp': 59,
#   'Humidity': 72,
#   'Cloudiness': 80,
#   'Wind Speed': 2.24,
#   'Country': 'NC',
#   'Date': '2020-08-27 19:51:35'},
#  {'City': 'Santa Lucia',
#   'Lat': 27.91,
#   'Lng': -15.54,
#   'Max Temp': 84.2,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 25.28,
#   'Country': 'ES',
#   'Date': '2020-08-27 19:51:32'},
#  {'City': 'Richards Bay',
#   'Lat': -28.78,
#   'Lng': 32.04,
#   'Max Temp': 67.93,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 16.98,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:42'},
#  {'City': 'Khuldabad',
#   'Lat': 20.05,
#   'Lng': 75.18,
#   'Max Temp': 70.72,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 10.65,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:42'},
#  {'City': 'Saku',
#   'Lat': 36.22,
#   'Lng': 138.48,
#   'Max Temp': 70,
#   'Humidity': 99,
#   'Cloudiness': 8,
#   'Wind Speed': 3.18,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:53:42'},
#  {'City': 'Inderka',
#   'Lat': 53.25,
#   'Lng': 46.26,
#   'Max Temp': 64.24,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:42'},
#  {'City': 'Ewa Beach',
#   'Lat': 21.32,
#   'Lng': -158.01,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Date': '2020-08-27 19:49:10'},
#  {'City': 'Palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 64.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.23,
#   'Country': 'US',
#   'Date': '2020-08-27 19:51:10'},
#  {'City': 'Waingapu',
#   'Lat': -9.66,
#   'Lng': 120.26,
#   'Max Temp': 74.75,
#   'Humidity': 80,
#   'Cloudiness': 2,
#   'Wind Speed': 10.02,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'Blytheville',
#   'Lat': 35.93,
#   'Lng': -89.92,
#   'Max Temp': 86,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 57.2,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 2.75,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'Clyde River',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 55.4,
#   'Humidity': 50,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.46,
#   'Lng': -122.43,
#   'Max Temp': 71.01,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'Meulaboh',
#   'Lat': 4.14,
#   'Lng': 96.13,
#   'Max Temp': 75.83,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.87,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.67,
#   'Lng': 72.89,
#   'Max Temp': 82.94,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33,
#   'Country': 'MV',
#   'Date': '2020-08-27 19:53:43'},
#  {'City': 'Imamoglu',
#   'Lat': 37.27,
#   'Lng': 35.66,
#   'Max Temp': 81,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'TR',
#   'Date': '2020-08-27 19:53:44'},
#  {'City': 'Kruisfontein',
#   'Lat': -34,
#   'Lng': 24.73,
#   'Max Temp': 53.01,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'ZA',
#   'Date': '2020-08-27 19:53:44'},
#  {'City': 'Kiri Buru',
#   'Lat': 22.08,
#   'Lng': 85.35,
#   'Max Temp': 70.57,
#   'Humidity': 92,
#   'Cloudiness': 94,
#   'Wind Speed': 4.54,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:53:44'},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 55.47,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:53:44'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Max Temp': 67.01,
#   'Humidity': 73,
#   'Cloudiness': 64,
#   'Wind Speed': 20.78,
#   'Country': 'NC',
#   'Date': '2020-08-27 19:53:44'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.82,
#   'Lng': -51.19,
#   'Max Temp': 44.6,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'GL',
#   'Date': '2020-08-27 19:53:44'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 41,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:53:45'},
#  {'City': 'Kastamonu',
#   'Lat': 41.5,
#   'Lng': 33.67,
#   'Max Temp': 57.42,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'TR',
#   'Date': '2020-08-27 19:53:45'},
#  {'City': 'Dunedin',
#   'Lat': -45.87,
#   'Lng': 170.5,
#   'Max Temp': 42.01,
#   'Humidity': 83,
#   'Cloudiness': 5,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Date': '2020-08-27 19:50:21'},
#  {'City': 'Nancha',
#   'Lat': 47.13,
# ...
#   'Country': 'GB',
#   'Date': '2020-08-27 19:54:24'},
#  {'City': 'Gisborne',
#   'Lat': -38.65,
#   'Lng': 178,
#   'Max Temp': 46.99,
#   'Humidity': 72,
#   'Cloudiness': 2,
#   'Wind Speed': 4,
#   'Country': 'NZ',
#   'Date': '2020-08-27 19:54:24'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 79.52,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.36,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:54:24'},
#  {'City': 'Ratholo',
#   'Lat': -22.72,
#   'Lng': 27.57,
#   'Max Temp': 59.95,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 10.27,
#   'Country': 'BW',
#   'Date': '2020-08-27 19:54:24'},
#  {'City': 'Kitgum',
#   'Lat': 3.28,
#   'Lng': 32.89,
#   'Max Temp': 67.14,
#   'Humidity': 93,
#   'Cloudiness': 67,
#   'Wind Speed': 1.81,
#   'Country': 'UG',
#   'Date': '2020-08-27 19:51:36'},
#  {'City': 'Victor Harbor',
#   'Lat': -35.57,
#   'Lng': 138.62,
#   'Max Temp': 45,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 4.29,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Bardiyah',
#   'Lat': 31.76,
#   'Lng': 25.09,
#   'Max Temp': 76.42,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 12.39,
#   'Country': 'LY',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Safford',
#   'Lat': 32.83,
#   'Lng': -109.71,
#   'Max Temp': 100.4,
#   'Humidity': 16,
#   'Cloudiness': 1,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Dong Hoi',
#   'Lat': 17.48,
#   'Lng': 106.6,
#   'Max Temp': 81,
#   'Humidity': 75,
#   'Cloudiness': 84,
#   'Wind Speed': 9.15,
#   'Country': 'VN',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Taksimo',
#   'Lat': 56.34,
#   'Lng': 114.88,
#   'Max Temp': 50.29,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 1.43,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.67,
#   'Max Temp': 75.4,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Country': 'SD',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Kampong Thum',
#   'Lat': 12.71,
#   'Lng': 104.89,
#   'Max Temp': 78.44,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'KH',
#   'Date': '2020-08-27 19:54:25'},
#  {'City': 'Romanovka',
#   'Lat': 51.74,
#   'Lng': 42.75,
#   'Max Temp': 69.75,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'Chandla',
#   'Lat': 25.08,
#   'Lng': 80.2,
#   'Max Temp': 81.82,
#   'Humidity': 81,
#   'Cloudiness': 82,
#   'Wind Speed': 6.85,
#   'Country': 'IN',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'Juegang',
#   'Lat': 32.32,
#   'Lng': 121.19,
#   'Max Temp': 82,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 1.52,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'Karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Max Temp': 74.75,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 6.89,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:50:12'},
#  {'City': 'Altay',
#   'Lat': 47.87,
#   'Lng': 88.12,
#   'Max Temp': 56.05,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'Chauk',
#   'Lat': 20.88,
#   'Lng': 94.82,
#   'Max Temp': 78.66,
#   'Humidity': 82,
#   'Cloudiness': 33,
#   'Wind Speed': 10.42,
#   'Country': 'MM',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'North Bend',
#   'Lat': 43.41,
#   'Lng': -124.22,
#   'Max Temp': 80.01,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 20.8,
#   'Country': 'US',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'Bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 40.77,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:26'},
#  {'City': 'Jalu',
#   'Lat': 29.03,
#   'Lng': 21.55,
#   'Max Temp': 80.24,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 16.04,
#   'Country': 'LY',
#   'Date': '2020-08-27 19:54:27'},
#  {'City': 'Chinsali',
#   'Lat': -10.54,
#   'Lng': 32.08,
#   'Max Temp': 67.91,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 7.85,
#   'Country': 'ZM',
#   'Date': '2020-08-27 19:54:27'},
#  {'City': 'Grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Max Temp': 50,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'IS',
#   'Date': '2020-08-27 19:54:27'},
#  {'City': 'Matay',
#   'Lat': 28.42,
#   'Lng': 30.78,
#   'Max Temp': 82.33,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 16.6,
#   'Country': 'EG',
#   'Date': '2020-08-27 19:54:27'},
#  {'City': 'Santo Antonio Do Ica',
#   'Lat': -3.1,
#   'Lng': -67.94,
#   'Max Temp': 88.3,
#   'Humidity': 54,
#   'Cloudiness': 95,
#   'Wind Speed': 1.14,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:54:27'},
#  {'City': 'San Juan',
#   'Lat': -31.54,
#   'Lng': -68.54,
#   'Max Temp': 70.92,
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 6.13,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:50:39'},
#  {'City': 'Sorong',
#   'Lat': -0.88,
#   'Lng': 131.25,
#   'Max Temp': 77.9,
#   'Humidity': 86,
#   'Cloudiness': 71,
#   'Wind Speed': 10.8,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:54:27'},
#  {'City': 'Perth',
#   'Lat': -31.93,
#   'Lng': 115.83,
#   'Max Temp': 59,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Trinidad',
#   'Lat': -14.83,
#   'Lng': -64.9,
#   'Max Temp': 95,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'BO',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Nibbar',
#   'Lat': 36.29,
#   'Lng': 8.77,
#   'Max Temp': 87.8,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'TN',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Zheleznodorozhnyy',
#   'Lat': 55.75,
#   'Lng': 38,
#   'Max Temp': 63,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Gberia Fotombu',
#   'Lat': 9.88,
#   'Lng': -11.17,
#   'Max Temp': 70.99,
#   'Humidity': 97,
#   'Cloudiness': 37,
#   'Wind Speed': 4.23,
#   'Country': 'SL',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Lamu',
#   'Lat': -2.27,
#   'Lng': 40.9,
#   'Max Temp': 76.03,
#   'Humidity': 80,
#   'Cloudiness': 0,
#   'Wind Speed': 13.91,
#   'Country': 'KE',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Opuwo',
#   'Lat': -18.06,
#   'Lng': 13.84,
#   'Max Temp': 62.96,
#   'Humidity': 31,
#   'Cloudiness': 64,
#   'Wind Speed': 6.76,
#   'Country': 'NA',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Cherusti',
#   'Lat': 55.55,
#   'Lng': 40.01,
#   'Max Temp': 59.02,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind Speed': 5.28,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:28'},
#  {'City': 'Kandrian',
#   'Lat': -6.22,
#   'Lng': 149.55,
#   'Max Temp': 78.6,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 12.97,
#   'Country': 'PG',
#   'Date': '2020-08-27 19:54:29'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.05,
#   'Lng': 39.51,
#   'Max Temp': 47.52,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 27.49,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:29'},
#  {'City': 'Morondava',
#   'Lat': -20.28,
#   'Lng': 44.28,
#   'Max Temp': 75.04,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 15.01,
#   'Country': 'MG',
#   'Date': '2020-08-27 19:54:29'},
#  {'City': 'Guaruja',
#   'Lat': -23.99,
#   'Lng': -46.26,
#   'Max Temp': 73.4,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:54:29'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.76,
#   'Max Temp': 80.01,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'IL',
#   'Date': '2020-08-27 19:54:29'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Max Temp': 59,
#   'Humidity': 33,
#   'Cloudiness': 40,
#   'Wind Speed': 18.34,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:51:45'},
#  {'City': 'Kristinehamn',
#   'Lat': 59.31,
#   'Lng': 14.11,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.66,
#   'Country': 'SE',
#   'Date': '2020-08-27 19:54:29'},
#  {'City': 'Moranbah',
#   'Lat': -22,
#   'Lng': 148.05,
#   'Max Temp': 52.65,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 9.62,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Novoselitskoye',
#   'Lat': 44.75,
#   'Lng': 43.44,
#   'Max Temp': 69.8,
#   'Humidity': 52,
#   'Cloudiness': 92,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Uray',
#   'Lat': 60.12,
#   'Lng': 64.78,
#   'Max Temp': 57.22,
#   'Humidity': 94,
#   'Cloudiness': 32,
#   'Wind Speed': 8.66,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Genhe',
#   'Lat': 50.78,
#   'Lng': 121.52,
#   'Max Temp': 49.42,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Bloomfield',
#   'Lat': 40.81,
#   'Lng': -74.19,
#   'Max Temp': 93,
#   'Humidity': 43,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Bourail',
#   'Lat': -21.57,
#   'Lng': 165.48,
#   'Max Temp': 63.64,
#   'Humidity': 72,
#   'Cloudiness': 53,
#   'Wind Speed': 4.74,
#   'Country': 'NC',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': 45.09,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Maxixe',
#   'Lat': -23.86,
#   'Lng': 35.35,
#   'Max Temp': 68.85,
#   'Humidity': 83,
#   'Cloudiness': 47,
#   'Wind Speed': 6.51,
#   'Country': 'MZ',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Itoman',
#   'Lat': 26.12,
#   'Lng': 127.67,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Ust-Uda',
#   'Lat': 54.17,
#   'Lng': 103.03,
#   'Max Temp': 55.4,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.74,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:31'},
#  {'City': 'Bam',
#   'Lat': 29.11,
#   'Lng': 58.36,
#   'Max Temp': 82.51,
#   'Humidity': 15,
#   'Cloudiness': 68,
#   'Wind Speed': 8.21,
#   'Country': 'IR',
#   'Date': '2020-08-27 19:54:31'},
#  {'City': 'Salinas',
#   'Lat': 36.68,
#   'Lng': -121.66,
#   'Max Temp': 66.2,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Date': '2020-08-27 19:54:30'},
#  {'City': 'Biak',
#   'Lat': -0.91,
#   'Lng': 122.88,
#   'Max Temp': 75.61,
#   'Humidity': 82,
#   'Cloudiness': 68,
#   'Wind Speed': 7.49,
#   'Country': 'ID',
#   'Date': '2020-08-27 19:54:31'},
#  {'City': 'Dauriya',
#   'Lat': 49.93,
#   'Lng': 116.87,
#   'Max Temp': 55.83,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 17.92,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:31'},
#  {'City': 'Zarate',
#   'Lat': -34.1,
#   'Lng': -59.03,
#   'Max Temp': 69.01,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'AR',
#   'Date': '2020-08-27 19:54:31'},
#  {'City': 'Songjianghe',
#   'Lat': 42.19,
#   'Lng': 127.48,
#   'Max Temp': 65.19,
#   'Humidity': 96,
#   'Cloudiness': 0,
#   'Wind Speed': 5.35,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Seabra',
#   'Lat': -12.42,
#   'Lng': -41.77,
#   'Max Temp': 78.17,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:52:48'},
#  {'City': 'Port Lincoln',
#   'Lat': -34.73,
#   'Lng': 135.87,
#   'Max Temp': 51.6,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 2.93,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Praya',
#   'Lat': 14.92,
#   'Lng': -23.51,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'CV',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Nicoya',
#   'Lat': 10.15,
#   'Lng': -85.45,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'CR',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Wuzhou',
#   'Lat': 23.48,
#   'Lng': 111.32,
#   'Max Temp': 73.2,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Riberalta',
#   'Lat': -10.98,
#   'Lng': -66.1,
#   'Max Temp': 100.42,
#   'Humidity': 22,
#   'Cloudiness': 5,
#   'Wind Speed': 2.71,
#   'Country': 'BO',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.23,
#   'Lng': 136.77,
#   'Max Temp': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 3,
#   'Wind Speed': 10.29,
#   'Country': 'AU',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Port-De-Bouc',
#   'Lat': 43.4,
#   'Lng': 4.98,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'FR',
#   'Date': '2020-08-27 19:54:32'},
#  {'City': 'Mabaruma',
#   'Lat': 8.2,
#   'Lng': -59.78,
#   'Max Temp': 86.38,
#   'Humidity': 66,
#   'Cloudiness': 92,
#   'Wind Speed': 6.6,
#   'Country': 'GY',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.17,
#   'Max Temp': 47.03,
#   'Humidity': 69,
#   'Cloudiness': 73,
#   'Wind Speed': 7.7,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Kolosovka',
#   'Lat': 56.47,
#   'Lng': 73.61,
#   'Max Temp': 52.81,
#   'Humidity': 90,
#   'Cloudiness': 54,
#   'Wind Speed': 4.68,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Gushikawa',
#   'Lat': 26.35,
#   'Lng': 127.87,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'JP',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'High Level',
#   'Lat': 58.52,
#   'Lng': -117.14,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Omegna',
#   'Lat': 45.88,
#   'Lng': 8.41,
#   'Max Temp': 73.99,
#   'Humidity': 72,
#   'Cloudiness': 15,
#   'Wind Speed': 1.99,
#   'Country': 'IT',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Ajdabiya',
#   'Lat': 30.76,
#   'Lng': 20.23,
#   'Max Temp': 77.77,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 15.35,
#   'Country': 'LY',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Shiyan',
#   'Lat': 32.65,
#   'Lng': 110.78,
#   'Max Temp': 70.29,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 1.45,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:33'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.92,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'GT',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Yugorsk',
#   'Lat': 61.31,
#   'Lng': 63.33,
#   'Max Temp': 56.91,
#   'Humidity': 96,
#   'Cloudiness': 7,
#   'Wind Speed': 7.4,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Capaci',
#   'Lat': 38.17,
#   'Lng': 13.24,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 21,
#   'Wind Speed': 6.93,
#   'Country': 'IT',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Pilar',
#   'Lat': -9.6,
#   'Lng': -35.96,
#   'Max Temp': 78.8,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'BR',
#   'Date': '2020-08-27 19:51:25'},
#  {'City': 'Sechura',
#   'Lat': -5.56,
#   'Lng': -80.82,
#   'Max Temp': 75.4,
#   'Humidity': 50,
#   'Cloudiness': 5,
#   'Wind Speed': 14.36,
#   'Country': 'PE',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Chiredzi',
#   'Lat': -21.05,
#   'Lng': 31.67,
#   'Max Temp': 65.03,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 5.53,
#   'Country': 'ZW',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Galle',
#   'Lat': 6.04,
#   'Lng': 80.22,
#   'Max Temp': 80.98,
#   'Humidity': 79,
#   'Cloudiness': 81,
#   'Wind Speed': 11.12,
#   'Country': 'LK',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Polunochnoye',
#   'Lat': 60.87,
#   'Lng': 60.42,
#   'Max Temp': 54.82,
#   'Humidity': 96,
#   'Cloudiness': 8,
#   'Wind Speed': 5.7,
#   'Country': 'RU',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Gaomi',
#   'Lat': 36.38,
#   'Lng': 119.75,
#   'Max Temp': 73,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'CN',
#   'Date': '2020-08-27 19:54:34'},
#  {'City': 'Bangassou',
#   'Lat': 4.74,
#   'Lng': 22.82,
#   'Max Temp': 71.74,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 0.89,
#   'Country': 'CF',
#   'Date': '2020-08-27 19:54:35'},
#  {'City': 'Ferrol',
#   'Lat': 43.48,
#   'Lng': -8.24,
#   'Max Temp': 68,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'ES',
#   'Date': '2020-08-27 19:52:36'},
#  {'City': 'Limbe',
#   'Lat': 4.02,
#   'Lng': 9.21,
#   'Max Temp': 78.8,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'CM',
#   'Date': '2020-08-27 19:54:35'}]

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Ulladulla -35.35  150.47     46.99        93           0        3.36
# 1   Tuktoyaktuk  69.45 -133.04     42.80        75          90       12.75
# 2         Kapaa  22.08 -159.32     82.99        69          20       12.75
# 3       Iqaluit  63.75  -68.51     59.00        41          75       11.41
# 4       Tortoli  39.93    9.66     80.60        94           0        6.93
# 5       Honiara  -9.43  159.95     75.20        94          75        4.70
# 6  Serafimovich  49.58   42.74     64.00        55         100        8.05
# 7   Yellowknife  62.46 -114.35     60.80        72          75       11.41
# 8    Nikolskoye  59.70   30.79     55.40        87          90        4.47
# 9       Rikitea -23.12 -134.97     67.93        61           0        1.39
#
#   Country                 Date
# 0      AU  2020-08-27 19:53:11
# 1      CA  2020-08-27 19:53:11
# 2      US  2020-08-27 19:53:11
# 3      CA  2020-08-27 19:51:51
# 4      IT  2020-08-27 19:53:12
# 5      SB  2020-08-27 19:52:53
# 6      RU  2020-08-27 19:53:12
# 7      CA  2020-08-27 19:50:51
# 8      RU  2020-08-27 19:53:12
# 9      PF  2020-08-27 19:53:12

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
